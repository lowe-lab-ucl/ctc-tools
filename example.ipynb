# %%
import matplotlib.pyplot as plt

from ctctools import load_ctc, load_images
from pathlib import Path

# %%
PATH = Path("/Users/arl/Documents/Data/Fluo-C2DL-Huh7/")
EXPERIMENT = "01"

# %%
images = load_images(PATH)

# %%
images
# Out:
# dask.array<_map_read_frame, shape=(30, 1024, 1024), dtype=uint8, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>

# %%
detections, graph = load_ctc(PATH, experiment=EXPERIMENT)

# %%
detections
# Out:
#      ID  time      x      y
# 0     1     0  281.0  242.0
# 1     1     1  277.0  242.0
# 2     1     2  277.0  242.0
# 3     1     3  272.0  245.0
# 4     1     4  272.0  245.0
# ..   ..   ...    ...    ...
# 946  37    25  148.0  801.0
# 947  37    26  148.0  800.0
# 948  37    27  149.0  800.0
# 949  37    28  149.0  800.0
# 950  37    29  149.0  800.0
#
# [951 rows x 4 columns]

# %%
graph
# Out:
# {29: 28, 32: 31, 34: 31}

# %%
plt.imshow(images[0, ...])
